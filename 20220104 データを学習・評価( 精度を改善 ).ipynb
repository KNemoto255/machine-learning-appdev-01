# %%
データ分類の精度（テスト精度）を改善させる方法を考える。
１、データ数を増やす
 →
２、ハイパーパラメータ・アルゴリズムを見直す
 →
３、モデルを見直す
 →
# Out:
#   Input In [1]
#     データ分類の精度（テスト精度）を改善させる方法を考える。
#             ^
# SyntaxError: invalid character '（' (U+FF08)

# %%
#データを学習・評価するためのモデルを定義する

import numpy as np
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import np_utils

# %%
classes = ["monkey", "boar", "crow"]
num_classes = len(classes)
image_size = 50

My_epochs=100
My_validation_split=0.25
My_decoder_name = "Animal_Decoder_aug
My_data_name = "npydata01_aug

# %%
#メイン関数
def main():
    #allow_pickle=Trueをnpyデータを読む際は追加
    X_train, X_test, Y_train, Y_test = np.load("./" + My_data_name + ".npy",allow_pickle=True)

    #説明変数 - 値を標準化する   
    X_train = X_train.astype("float") / 256
    X_test = X_test.astype("float") / 256

    #目的変数はワンホットベクター形式にする
    Y_train = np_utils.to_categorical(Y_train, num_classes)
    Y_test = np_utils.to_categorical(Y_test, num_classes)

    #学習を開始
    model = model_train(X_train, Y_train)
    #model_eval(model, X_test, Y_test)

# %%
#モデルの学習
def model_train(X,Y):
    
    model = Sequential()
    #一番最初の入力層には、モデルの画像サイズを使う
    #全結合をした後ドロップアウトすることで若干精度が向上する
    model.add(Conv2D(filters=32, kernel_size=(3,3), padding="same", input_shape=X.shape[1:]))
    model.add(Activation("relu"))
    model.add(Conv2D(filters=32, kernel_size=(3,3)))
    model.add(Activation("relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(filters=64, kernel_size=(3,3),padding="same", input_shape=X.shape[1:]))
    model.add(Activation("relu"))
    model.add(Conv2D(filters=64, kernel_size=(3,3)))
    model.add(Activation("relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    #全結合層に入力するため、Flattenレイヤーで4階テンソルとなっている出力値を2階テンソルに直す          
    model.add(Flatten())

    #全結合層
    model.add(Dense(units=512))
    model.add(Activation("relu"))
    model.add(Dropout(0.5))
    model.add(Dense(units=3))
    model.add(Activation("softmax"))
    model.output_shape

    #モデルをコンパイル + 損失関数を定義
    model.compile(loss = "categorical_crossentropy", optimizer="adam", metrics = ["accuracy"])

    #モデルを学習してフィッティングする
    model.fit(X, Y, batch_size=32, epochs=My_epochs, validation_split=My_validation_split)

    #学習したモデルを保存する
    model.save("./" + My_decoder_name + ".h5")

# %%
def model_eval(model, X, Y):

    scores = model.evaluate(X, Y, verbose = 1)
    print("更新された損失量", scores[0])
    print("テスト精度", scores[1])

# %%
if __name__ == "__main__":
    main()
# Out:
# Epoch 1/100
# 11/11 [==============================] - 4s 212ms/step - loss: 1.1390 - accuracy: 0.3323 - val_loss: 1.0969 - val_accuracy: 0.3540
# Epoch 2/100
# 11/11 [==============================] - 2s 190ms/step - loss: 1.0957 - accuracy: 0.3234 - val_loss: 1.0798 - val_accuracy: 0.3982
# Epoch 3/100
# 11/11 [==============================] - 2s 191ms/step - loss: 1.0789 - accuracy: 0.3620 - val_loss: 1.0330 - val_accuracy: 0.4867
# Epoch 4/100
# 11/11 [==============================] - 3s 242ms/step - loss: 1.0555 - accuracy: 0.4392 - val_loss: 1.0330 - val_accuracy: 0.3982
# Epoch 5/100
# 11/11 [==============================] - 3s 240ms/step - loss: 1.0170 - accuracy: 0.4866 - val_loss: 0.9813 - val_accuracy: 0.4513
# Epoch 6/100
# 11/11 [==============================] - 2s 197ms/step - loss: 0.9668 - accuracy: 0.5045 - val_loss: 0.9667 - val_accuracy: 0.4690
# Epoch 7/100
# 11/11 [==============================] - 3s 237ms/step - loss: 0.8617 - accuracy: 0.5964 - val_loss: 1.1105 - val_accuracy: 0.4513
# Epoch 8/100
# 11/11 [==============================] - 2s 195ms/step - loss: 0.8372 - accuracy: 0.6380 - val_loss: 0.8934 - val_accuracy: 0.5575
# Epoch 9/100
# 11/11 [==============================] - 2s 191ms/step - loss: 0.7551 - accuracy: 0.6617 - val_loss: 0.9131 - val_accuracy: 0.5664
# Epoch 10/100
# 11/11 [==============================] - 2s 188ms/step - loss: 0.6869 - accuracy: 0.7003 - val_loss: 0.8787 - val_accuracy: 0.5752
# Epoch 11/100
# 11/11 [==============================] - 2s 189ms/step - loss: 0.6337 - accuracy: 0.7448 - val_loss: 0.9049 - val_accuracy: 0.6106
# Epoch 12/100
# 11/11 [==============================] - 2s 188ms/step - loss: 0.5929 - accuracy: 0.7389 - val_loss: 1.1065 - val_accuracy: 0.5398
# Epoch 13/100
# 11/11 [==============================] - 2s 195ms/step - loss: 0.5258 - accuracy: 0.7923 - val_loss: 1.1670 - val_accuracy: 0.5929
# Epoch 14/100
# 11/11 [==============================] - 2s 192ms/step - loss: 0.4330 - accuracy: 0.8131 - val_loss: 1.1666 - val_accuracy: 0.5929
# Epoch 15/100
# 11/11 [==============================] - 2s 189ms/step - loss: 0.4731 - accuracy: 0.8071 - val_loss: 1.1781 - val_accuracy: 0.5752
# Epoch 16/100
# 11/11 [==============================] - 2s 188ms/step - loss: 0.5043 - accuracy: 0.7804 - val_loss: 1.2386 - val_accuracy: 0.5487
# Epoch 17/100
# 11/11 [==============================] - 2s 189ms/step - loss: 0.4206 - accuracy: 0.8368 - val_loss: 1.3122 - val_accuracy: 0.5664
# Epoch 18/100
# 11/11 [==============================] - 2s 192ms/step - loss: 0.3022 - accuracy: 0.8902 - val_loss: 1.7313 - val_accuracy: 0.5575
# Epoch 19/100
# 11/11 [==============================] - 2s 192ms/step - loss: 0.2683 - accuracy: 0.8961 - val_loss: 1.5689 - val_accuracy: 0.5398
# Epoch 20/100
# 11/11 [==============================] - 2s 192ms/step - loss: 0.2660 - accuracy: 0.8961 - val_loss: 1.7886 - val_accuracy: 0.5664
# Epoch 21/100
# 11/11 [==============================] - 2s 188ms/step - loss: 0.3085 - accuracy: 0.8872 - val_loss: 1.4093 - val_accuracy: 0.5929
# Epoch 22/100
# 11/11 [==============================] - 2s 194ms/step - loss: 0.2597 - accuracy: 0.9139 - val_loss: 1.3176 - val_accuracy: 0.5664
# Epoch 23/100
# 11/11 [==============================] - 2s 198ms/step - loss: 0.2417 - accuracy: 0.8991 - val_loss: 1.5164 - val_accuracy: 0.5841
# Epoch 24/100
# 11/11 [==============================] - 2s 203ms/step - loss: 0.1804 - accuracy: 0.9318 - val_loss: 1.9743 - val_accuracy: 0.5752
# Epoch 25/100
# 11/11 [==============================] - 2s 205ms/step - loss: 0.2151 - accuracy: 0.9258 - val_loss: 1.9185 - val_accuracy: 0.5575
# Epoch 26/100
# 11/11 [==============================] - 2s 211ms/step - loss: 0.1282 - accuracy: 0.9555 - val_loss: 2.0935 - val_accuracy: 0.5929
# Epoch 27/100
# 11/11 [==============================] - 3s 234ms/step - loss: 0.0878 - accuracy: 0.9733 - val_loss: 2.2826 - val_accuracy: 0.6018
# Epoch 28/100
# 11/11 [==============================] - 3s 249ms/step - loss: 0.0636 - accuracy: 0.9822 - val_loss: 2.0360 - val_accuracy: 0.5929
# Epoch 29/100
# 11/11 [==============================] - 3s 232ms/step - loss: 0.0724 - accuracy: 0.9733 - val_loss: 2.2286 - val_accuracy: 0.5841
# Epoch 30/100
# 11/11 [==============================] - 2s 212ms/step - loss: 0.0740 - accuracy: 0.9674 - val_loss: 2.1399 - val_accuracy: 0.5841
# Epoch 31/100
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0924 - accuracy: 0.9674 - val_loss: 2.9449 - val_accuracy: 0.5310
# Epoch 32/100
# 11/11 [==============================] - 2s 201ms/step - loss: 0.1022 - accuracy: 0.9763 - val_loss: 2.7532 - val_accuracy: 0.5752
# Epoch 33/100
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0877 - accuracy: 0.9763 - val_loss: 2.7835 - val_accuracy: 0.5575
# Epoch 34/100
# 11/11 [==============================] - 2s 211ms/step - loss: 0.0767 - accuracy: 0.9763 - val_loss: 2.8766 - val_accuracy: 0.5664
# Epoch 35/100
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0537 - accuracy: 0.9822 - val_loss: 2.4859 - val_accuracy: 0.5841
# Epoch 36/100
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0620 - accuracy: 0.9852 - val_loss: 2.9039 - val_accuracy: 0.5664
# Epoch 37/100
# 11/11 [==============================] - 2s 188ms/step - loss: 0.0555 - accuracy: 0.9881 - val_loss: 2.8151 - val_accuracy: 0.5310
# Epoch 38/100
# 11/11 [==============================] - 2s 188ms/step - loss: 0.0597 - accuracy: 0.9852 - val_loss: 3.0455 - val_accuracy: 0.5310
# Epoch 39/100
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0779 - accuracy: 0.9763 - val_loss: 3.1174 - val_accuracy: 0.5310
# Epoch 40/100
# 11/11 [==============================] - 2s 198ms/step - loss: 0.0922 - accuracy: 0.9614 - val_loss: 4.0511 - val_accuracy: 0.4867
# Epoch 41/100
# 11/11 [==============================] - 2s 199ms/step - loss: 0.0959 - accuracy: 0.9822 - val_loss: 2.6548 - val_accuracy: 0.5221
# Epoch 42/100
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0691 - accuracy: 0.9792 - val_loss: 2.4004 - val_accuracy: 0.5752
# Epoch 43/100
# 11/11 [==============================] - 2s 188ms/step - loss: 0.0313 - accuracy: 0.9941 - val_loss: 2.8910 - val_accuracy: 0.5929
# Epoch 44/100
# 11/11 [==============================] - 2s 188ms/step - loss: 0.0674 - accuracy: 0.9703 - val_loss: 2.6816 - val_accuracy: 0.5575
# Epoch 45/100
# 11/11 [==============================] - 2s 205ms/step - loss: 0.1043 - accuracy: 0.9792 - val_loss: 2.6155 - val_accuracy: 0.5929
# Epoch 46/100
# 11/11 [==============================] - 2s 188ms/step - loss: 0.1210 - accuracy: 0.9644 - val_loss: 3.1678 - val_accuracy: 0.5841
# Epoch 47/100
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0426 - accuracy: 0.9822 - val_loss: 3.1395 - val_accuracy: 0.5929
# Epoch 48/100
# 11/11 [==============================] - 2s 188ms/step - loss: 0.0489 - accuracy: 0.9852 - val_loss: 3.9593 - val_accuracy: 0.5398
# Epoch 49/100
# 11/11 [==============================] - 2s 189ms/step - loss: 0.0352 - accuracy: 0.9881 - val_loss: 3.3248 - val_accuracy: 0.5664
# Epoch 50/100
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0240 - accuracy: 0.9941 - val_loss: 3.3323 - val_accuracy: 0.5487
# Epoch 51/100
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0475 - accuracy: 0.9881 - val_loss: 3.1600 - val_accuracy: 0.5398
# Epoch 52/100
# 11/11 [==============================] - 2s 190ms/step - loss: 0.0357 - accuracy: 0.9911 - val_loss: 3.5409 - val_accuracy: 0.5664
# Epoch 53/100
# 11/11 [==============================] - 2s 199ms/step - loss: 0.0924 - accuracy: 0.9703 - val_loss: 3.0954 - val_accuracy: 0.5221
# Epoch 54/100
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0917 - accuracy: 0.9763 - val_loss: 2.4999 - val_accuracy: 0.5664
# Epoch 55/100
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0309 - accuracy: 0.9911 - val_loss: 2.9171 - val_accuracy: 0.5752
# Epoch 56/100
# 11/11 [==============================] - 2s 198ms/step - loss: 0.0413 - accuracy: 0.9792 - val_loss: 2.8161 - val_accuracy: 0.5929
# Epoch 57/100
# 11/11 [==============================] - 2s 191ms/step - loss: 0.0207 - accuracy: 0.9941 - val_loss: 3.1044 - val_accuracy: 0.5929
# Epoch 58/100
# 11/11 [==============================] - 2s 188ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 3.3065 - val_accuracy: 0.6018
# Epoch 59/100
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0185 - accuracy: 0.9970 - val_loss: 3.2635 - val_accuracy: 0.5841
# Epoch 60/100
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0108 - accuracy: 0.9970 - val_loss: 3.6957 - val_accuracy: 0.5841
# Epoch 61/100
# 11/11 [==============================] - 2s 189ms/step - loss: 0.0138 - accuracy: 0.9941 - val_loss: 3.4731 - val_accuracy: 0.5929
# Epoch 62/100
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0276 - accuracy: 0.9941 - val_loss: 3.6597 - val_accuracy: 0.5664
# Epoch 63/100
# 11/11 [==============================] - 2s 191ms/step - loss: 0.0206 - accuracy: 0.9911 - val_loss: 3.4880 - val_accuracy: 0.5310
# Epoch 64/100
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 4.0169 - val_accuracy: 0.5575
# Epoch 65/100
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0308 - accuracy: 0.9970 - val_loss: 3.3071 - val_accuracy: 0.5664
# Epoch 66/100
# 11/11 [==============================] - 2s 190ms/step - loss: 0.0247 - accuracy: 0.9852 - val_loss: 4.1787 - val_accuracy: 0.5310
# Epoch 67/100
# 11/11 [==============================] - 2s 190ms/step - loss: 0.0388 - accuracy: 0.9911 - val_loss: 3.2545 - val_accuracy: 0.5841
# Epoch 68/100
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0151 - accuracy: 0.9970 - val_loss: 3.2111 - val_accuracy: 0.6018
# Epoch 69/100
# 11/11 [==============================] - 2s 188ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 3.8988 - val_accuracy: 0.5929
# Epoch 70/100
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0125 - accuracy: 0.9941 - val_loss: 3.6684 - val_accuracy: 0.5929
# Epoch 71/100
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 3.6536 - val_accuracy: 0.6372
# Epoch 72/100
# 11/11 [==============================] - 2s 189ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 3.8130 - val_accuracy: 0.6372
# Epoch 73/100
# 11/11 [==============================] - 2s 190ms/step - loss: 0.0330 - accuracy: 0.9941 - val_loss: 3.4391 - val_accuracy: 0.6018
# Epoch 74/100
# 11/11 [==============================] - 2s 198ms/step - loss: 0.0121 - accuracy: 0.9970 - val_loss: 3.5784 - val_accuracy: 0.6018
# Epoch 75/100
# 11/11 [==============================] - 2s 199ms/step - loss: 0.0075 - accuracy: 0.9970 - val_loss: 3.6956 - val_accuracy: 0.5664
# Epoch 76/100
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0078 - accuracy: 0.9970 - val_loss: 4.1327 - val_accuracy: 0.6283
# Epoch 77/100
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0643 - accuracy: 0.9911 - val_loss: 3.2784 - val_accuracy: 0.6106
# Epoch 78/100
# 11/11 [==============================] - 2s 194ms/step - loss: 0.0522 - accuracy: 0.9911 - val_loss: 3.4193 - val_accuracy: 0.5929
# Epoch 79/100
# 11/11 [==============================] - 2s 215ms/step - loss: 0.0385 - accuracy: 0.9852 - val_loss: 3.1343 - val_accuracy: 0.5841
# Epoch 80/100
# 11/11 [==============================] - 2s 216ms/step - loss: 0.0697 - accuracy: 0.9941 - val_loss: 2.9618 - val_accuracy: 0.5752
# Epoch 81/100
# 11/11 [==============================] - 2s 220ms/step - loss: 0.0377 - accuracy: 0.9881 - val_loss: 3.2345 - val_accuracy: 0.5664
# Epoch 82/100
# 11/11 [==============================] - 3s 257ms/step - loss: 0.0245 - accuracy: 0.9881 - val_loss: 3.3411 - val_accuracy: 0.5752
# Epoch 83/100
# 11/11 [==============================] - 3s 235ms/step - loss: 0.0336 - accuracy: 0.9941 - val_loss: 3.2141 - val_accuracy: 0.6018
# Epoch 84/100
# 11/11 [==============================] - 2s 215ms/step - loss: 0.0206 - accuracy: 0.9941 - val_loss: 4.2960 - val_accuracy: 0.5664
# Epoch 85/100
# 11/11 [==============================] - 2s 212ms/step - loss: 0.0181 - accuracy: 0.9970 - val_loss: 3.6074 - val_accuracy: 0.5929
# Epoch 86/100
# 11/11 [==============================] - 2s 198ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 3.8199 - val_accuracy: 0.5929
# Epoch 87/100
# 11/11 [==============================] - 2s 220ms/step - loss: 0.0081 - accuracy: 0.9970 - val_loss: 3.4617 - val_accuracy: 0.6018
# Epoch 88/100
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 3.2458 - val_accuracy: 0.5929
# Epoch 89/100
# 11/11 [==============================] - 3s 240ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 3.7793 - val_accuracy: 0.5841
# Epoch 90/100
# 11/11 [==============================] - 3s 271ms/step - loss: 0.0079 - accuracy: 0.9970 - val_loss: 3.8063 - val_accuracy: 0.5929
# Epoch 91/100
# 11/11 [==============================] - 3s 252ms/step - loss: 0.0200 - accuracy: 0.9941 - val_loss: 3.6974 - val_accuracy: 0.5752
# Epoch 92/100
# 11/11 [==============================] - 3s 229ms/step - loss: 0.0698 - accuracy: 0.9911 - val_loss: 3.6584 - val_accuracy: 0.6018
# Epoch 93/100
# 11/11 [==============================] - 3s 249ms/step - loss: 0.0874 - accuracy: 0.9763 - val_loss: 2.6008 - val_accuracy: 0.5929
# Epoch 94/100
# 11/11 [==============================] - 2s 219ms/step - loss: 0.0381 - accuracy: 0.9881 - val_loss: 3.1936 - val_accuracy: 0.5841
# Epoch 95/100
# 11/11 [==============================] - 2s 215ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 3.3217 - val_accuracy: 0.6106
# Epoch 96/100
# 11/11 [==============================] - 2s 222ms/step - loss: 0.0093 - accuracy: 0.9970 - val_loss: 3.7535 - val_accuracy: 0.5929
# Epoch 97/100
# 11/11 [==============================] - 2s 209ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 3.7524 - val_accuracy: 0.5929
# Epoch 98/100
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 3.8413 - val_accuracy: 0.5929
# Epoch 99/100
# 11/11 [==============================] - 2s 191ms/step - loss: 0.0046 - accuracy: 0.9970 - val_loss: 3.9488 - val_accuracy: 0.5841
# Epoch 100/100
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 3.9360 - val_accuracy: 0.5664
